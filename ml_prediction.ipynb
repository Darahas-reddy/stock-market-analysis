# %% [markdown]
# <a href="https://colab.research.google.com/github/Darahas-reddy/stock-market-analysis/blob/main/ml_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load Data
data = pd.read_csv("/content/drive/MyDrive/stock-market-analysis/stocks_cleaned.csv")

# Use one stock for prediction (AAPL)
df = data[['AAPL']].copy()

# Create Target Column
df['Prediction'] = df['AAPL'].shift(-1)

# Features & Labels
X = df[['AAPL']][:-1]
y = df['Prediction'][:-1]

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)

# Output
print("Sample Predictions:")
print(predictions[:10])
# Out:
# Sample Predictions:
# [139.71527161 169.976323   145.87444189  66.87358261 142.97733133
#  171.71428248 170.41671078 131.46461635 149.66522519 131.43560149]
